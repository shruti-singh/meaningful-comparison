# %% [markdown]
# # Text and Tables Extraction on ICLR Data - PART2
#
# This is for the references of ICLR papers

# %%
import pickle
from collections import defaultdict
import re
import glob

# %%
from pathlib import Path
from axcell.helpers.paper_extractor import PaperExtractor
from axcell.data.paper_collection import PaperCollection
from axcell.models.structure import TableType, TableStructurePredictor, TableTypePredictor
# from axcell.helpers.results_extractor import ResultsExtractor

# %% [markdown]
# ## Load the paper references keys for steering

# %%
with open('iclr_ref_arxiv_map.pkl', "rb") as f:
    iclr_ref_arxiv_map = pickle.load(f)

# %% [markdown]
# ## Run extraction one by one

# %%
ROOT_PATH = Path('data')
MODELS_PATH = Path('models')

SOURCES_PATH = ROOT_PATH / 'sources'
PAPERS_PATH = ROOT_PATH / 'papers'

# %%
extract = PaperExtractor(ROOT_PATH)

# %%
models_path = Path(MODELS_PATH)
ttp = TableTypePredictor(models_path, "table-type-classifier.pth")
pc = PaperCollection.from_files(PAPERS_PATH)
# Out:
# /home/singh_shruti/anaconda3/envs/axcell/lib/python3.7/site-packages/torch/serialization.py:453: SourceChangeWarning: source code of class 'torch.nn.modules.loss.BCEWithLogitsLoss' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /home/singh_shruti/anaconda3/envs/axcell/lib/python3.7/site-packages/torch/serialization.py:453: SourceChangeWarning: source code of class 'fastai.text.models.awd_lstm.AWD_LSTM' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# ...

# %%
table_labels = {TableType.SOTA: 'leaderboard', TableType.ABLATION: 'ablation', TableType.IRRELEVANT: 'irrelevant'}

# %%
status_count = 0
err_count = 0
unextracted_papers = []
err_paper_ids = []
unextracted_paper_ids = []
status_count = max(len(leaderboard_table_refs), len(leaderboard_refs))
err_count = 0
errs_ids = []

leaderboard_table_refs = defaultdict(dict)
leaderboard_refs = defaultdict(dict)

# %%
already_computed = list(set(list(leaderboard_table_refs.keys()) + list(leaderboard_refs.keys())))

# %%
len(already_computed), already_computed[0:3], status_count, err_count, len(unextracted_papers)
# Out:
# (0, [], 5, 0, 0)

# %%
total = len(iclr_ref_arxiv_map)
count = 0

# First extract all - i.e. unpack and load htmls
for k, v in iclr_ref_arxiv_map.items():
    count += 1
    if count%10==0:
        print(count, total)
    try:
        path_split = v.split(".")
        # Extraction
        extract(SOURCES_PATH / path_split[0] / v)
    except Exception as ex:
        print(k, v)
# Out:
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 647191 1712.04248
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# 10 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# ...

# %%
count, total
# Out:
# (2328, 2328)

# %%
for k, v in iclr_ref_arxiv_map.items():
    if not (k in already_computed or k in err_pape0==r_ids or k in unextracted_paper_ids):
        if v:
            if status_count % 10 == 0:
                print("Status: ", status_count)
                with open("REF_leaderboard_table_refs.pkl", "wb") as some_file:
                    pickle.dump(leaderboard_table_refs, some_file)
                with open("REF_leaderboard_refs.pkl", "wb") as some_file:
                    pickle.dump(leaderboard_refs, some_file)
                    
            try:
                path_split = v.split(".")

                # Extraction
                # extract(SOURCES_PATH / path_split[0] / v)

                paper = pc.get_by_id(v)
                
                if not paper:
                    unextracted_papers.append((k, v))
                    continue
                
                print(k)
                
                if len(paper.tables) > 0:                    
                    # Add table type if absent
                    if paper.tables[0].gold_tags == "":
                        tables_types = ttp.predict(paper, paper.tables)
                        for table, table_type in zip(paper.tables, tables_types):
                            table.gold_tags = table_labels[table_type]
                    
                    #Count the different types of tables
                    table_type_count = [0, 0, 0]
                    for tt in paper.tables:
                        if tt.gold_tags.lower().strip() == "leaderboard":
                            table_type_count[0] = table_type_count[0] + 1
                        elif tt.gold_tags.lower().strip() == "ablation":
                            table_type_count[1] = table_type_count[1] + 1
                        elif tt.gold_tags.lower().strip() == "irrelevant":
                            table_type_count[2] = table_type_count[2] + 1
                        else:
                            print("Unknown table type: ", tt.gold_tags)
                    
                    # Save table stat in leaderboard_table_refs
                    leaderboard_table_refs[k]["tcount"] = [len(paper.tables), table_type_count[0], table_type_count[1], table_type_count[2]]
                else:
                    leaderboard_table_refs[k]["tcount"] = [0, 0, 0, 0]
                
                leaderboard_table_refs[k]["table_labels"] = []
                for tablerol in paper.tables:
                    leaderboard_table_refs[k]["table_labels"].append((tablerol.gold_tags,))
                
                if (leaderboard_table_refs[k]["tcount"][1]+leaderboard_table_refs[k]["tcount"][2]) > 0:
                    leaderboard_refs[k]["refs"] = {}
                
                # If sota/leaderboard tables present, extract references from them
                if leaderboard_table_refs[k]["tcount"][1] > 0:
                    leaderboard_refs[k]["refs"]["ldb"] = []
                    leaderboard_refs[k]["count"] = 0
                    for iterid, table in enumerate(paper.tables):
                        idx = iterid + 1
                        if table.gold_tags == "leaderboard":
                            
                            table_dir_path = "/home/singh_shruti/workspace/axcell_ws/axcell/notebooks/data/papers/" + path_split[0] + "/" + v
                            table_files = glob.glob(table_dir_path+"/*.csv")
                            table_files_stripped = [tfs.rsplit("/", 1)[1] for tfs in table_files]
                            
                            candidate_name = "table_" + "{:02d}".format(idx) + ".csv"
                            if candidate_name in table_files_stripped:
                                cannot_use_f = open(table_dir_path + "/" + candidate_name, "r")
                                for line in cannot_use_f:
                                    m = re.findall("<ref id=[0-9a-zA-Z'-]*>[a-zA-Z 0-9\.]*</ref>", line)
                                    for iim in m:
                                        leaderboard_refs[k]["refs"]["ldb"].append(iim)
                                        leaderboard_refs[k]["count"] += 1
                            else:
                                print("For {} cannot find leaderboard table file: {}".format(k, candidate_name))
                            
                    leaderboard_refs[k]["refs"]["ldb"] = list(set(leaderboard_refs[k]["refs"]["ldb"]))
                    
                if leaderboard_table_refs[k]["tcount"][2] > 0:
                    leaderboard_refs[k]["refs"]["abl"] = []
                    for iterid, table in enumerate(paper.tables):
                        idx = iterid + 1
                        if table.gold_tags == "ablation":
                            
                            table_dir_path = "/home/singh_shruti/workspace/axcell_ws/axcell/notebooks/data/papers/" + path_split[0] + "/" + v
                            table_files = glob.glob(table_dir_path+"/*.csv")
                            table_files_stripped = [tfs.rsplit("/", 1)[1] for tfs in table_files]
                            
                            candidate_name = "table_" + "{:02d}".format(idx) + ".csv"
                            if candidate_name in table_files_stripped:
                                cannot_use_f = open(table_dir_path + "/" + candidate_name, "r")
                                for line in cannot_use_f:
                                    m = re.findall("<ref id=[0-9a-zA-Z'-]*>[a-zA-Z 0-9\.]*</ref>", line)
                                    for iim in m:
                                        leaderboard_refs[k]["refs"]["abl"].append(iim)
                            else:
                                print("For {} cannot find ablation table file: {}".format(k, candidate_name))
                            
                    leaderboard_refs[k]["refs"]["abl"] = list(set(leaderboard_refs[k]["refs"]["abl"]))
                            
                status_count += 1
            except Exception as ex:
                print(k, v)
                print("Error: ", ex)
                err_count += 1
                errs_ids.append((k, v))
# Out:
# 1179651
# 1179653
# 598027
# 1163279
# 557076
# Status:  10
# 983062
# 647191
# 557082
# 229423
# 172080
# 622648
# 319548
# 327741
# 622657
# 1138755
# Status:  20
# 1155139
# 155719
# 41035
# 737358
# 1171539
# 1163347
# 540762
# 1187930
# 655452
# 106587
# Status:  30
# 82026
# 1187952
# 155762
# 1163380
# 1081461
# 385142
# 1171574
# For 1171574 cannot find leaderboard table file: table_02.csv
# For 1171574 cannot find leaderboard table file: table_04.csv
# For 1171574 cannot find ablation table file: table_03.csv
# For 1171574 cannot find ablation table file: table_05.csv
# 868479
# 368768
# 868481
# Status:  40
# 32898
# 368771
# 860290
# 139398
# 1056902
# 1155208
# 958605
# 1147022
# 1122449
# 163988
# Status:  50
# 1155227
# 180383
# 73894
# 1171624
# 1040553
# 1155242
# 1007786
# 1196205
# 1171634
# 860339
# Status:  60
# 229558
# 229559
# 1015990
# 123068
# 1032383
# 1138883
# 827588
# 139462
# 65737
# 942286
# Status:  70
# 1163474
# 16595
# 409813
# 483547
# 106720
# ...

# %%
status_count, len(unextracted_papers), 2158+175
# Out:
# (2158, 175, 2333)

# %%
len(leaderboard_refs), len(leaderboard_table_refs), 2153+175
# Out:
# (1668, 2153, 2328)

# %%
list(leaderboard_refs.items())[0:2]
# Out:
# [(1179651,
#   {'refs': {'ldb': ["<ref id='bib-bib5'>5</ref>",
#      "<ref id='bib-bib34'>34</ref>",
#      "<ref id='bib-bib43'>43</ref>",
#      "<ref id='bib-bib31'>31</ref>",
#      "<ref id='bib-bib32'>32</ref>"],
#     'abl': []},
#    'count': 5}),
#  (1179653, {'refs': {'ldb': [], 'abl': []}, 'count': 0})]

# %%
list(leaderboard_table_refs.items())[0:2]
# Out:
# [(1179651,
#   {'tcount': [9, 6, 1, 2],
#    'table_labels': [('irrelevant',),
#     ('irrelevant',),
#     ('leaderboard',),
#     ('leaderboard',),
#     ('ablation',),
#     ('leaderboard',),
#     ('leaderboard',),
#     ('leaderboard',),
#     ('leaderboard',)]}),
#  (1179653,
#   {'tcount': [9, 4, 5, 0],
#    'table_labels': [('leaderboard',),
#     ('leaderboard',),
#     ('ablation',),
#     ('ablation',),
#     ('ablation',),
#     ('leaderboard',),
#     ('ablation',),
#     ('ablation',),
#     ('leaderboard',)]})]

# %% [markdown]
# # ldb table present but no references

# %%
zero_refs = 0

for k in leaderboard_table_refs:
    if not k in unextracted_papers and (leaderboard_table_refs[k]['tcount'][1] + leaderboard_table_refs[k]['tcount'][2]) == 0:
        zero_refs += 1
        print("No refs: ", k)
    if (leaderboard_table_refs[k]['tcount'][1] + leaderboard_table_refs[k]['tcount'][2]) > 0 and not k in leaderboard_refs:
        print("Is there a mistake somewhere?:", k)
# Out:
# No refs:  598027
# No refs:  557076
# No refs:  647191
# No refs:  327741
# No refs:  1171539
# No refs:  540762
# No refs:  868481
# No refs:  368771
# No refs:  1147022
# No refs:  163988
# No refs:  1155227
# No refs:  860339
# No refs:  106720
# No refs:  671972
# No refs:  1155304
# No refs:  1147188
# No refs:  1048899
# No refs:  942483
# No refs:  328106
# No refs:  205248
# No refs:  360922
# No refs:  1163743
# No refs:  1122786
# No refs:  475630
# No refs:  1163769
# No refs:  1155584
# No refs:  705037
# No refs:  696851
# No refs:  1040928
# No refs:  213553
# No refs:  270911
# No refs:  639555
# No refs:  180805
# No refs:  287334
# No refs:  107113
# No refs:  279176
# No refs:  819849
# No refs:  459424
# No refs:  1155754
# No refs:  574126
# No refs:  901811
# No refs:  1082054
# No refs:  1155803
# No refs:  262920
# No refs:  353047
# No refs:  992046
# No refs:  279371
# No refs:  181085
# No refs:  820065
# No refs:  713621
# No refs:  1098664
# ...

# %%
print(zero_refs, 1668 + 485, 1668 + 485 + 175)
# Out:
# 485 2153 2328

# %%
nk = 630527




leaderboard_table_refs[nk], iclr_ref_arxiv_map[nk]
# Out:
# ({'tcount': [0, 0, 0, 0], 'table_labels': []}, '1506.08700')

# %% [markdown]
# ## One weird thing for these papers is that there are no leaderboard/ablation tables in around 485 papers out of 2153 papers (2153 = 2328 - 175)

# %% [markdown]
# ## Counting papers that have one ldb/abl tables and at least one reference

# %%
zero_refs_but_ldb = []
not_in_ldb_refs = []
succ = 0

for k in leaderboard_table_refs:
    if not k in unextracted_papers and (leaderboard_table_refs[k]['tcount'][1] + leaderboard_table_refs[k]['tcount'][2]) >= 0:
        if k in leaderboard_refs:
            if 'count' in leaderboard_refs and leaderboard_refs[k]['count'] <= 0:
                zero_refs_but_ldb.append(k)
            else:
                succ+=1
        else:
            not_in_ldb_refs.append(k)
    else:
        msg = "We dont care about these. We have looked into these above already. These are 175 + 485 papers for each of the above conditions resp."

# %%
len(leaderboard_refs), len(zero_refs_but_ldb), len(not_in_ldb_refs), succ
# Out:
# (1668, 0, 485, 1668)

# %% [markdown]
# So basically if the key is not in leaderboard_refs, then it means that no reference was extracted from the ldb/abl tables

# %%
len(leaderboard_refs), list(leaderboard_refs.items())[0:2]
# Out:
# (1668,
#  [(1179651,
#    {'refs': {'ldb': ["<ref id='bib-bib5'>5</ref>",
#       "<ref id='bib-bib34'>34</ref>",
#       "<ref id='bib-bib43'>43</ref>",
#       "<ref id='bib-bib31'>31</ref>",
#       "<ref id='bib-bib32'>32</ref>"],
#      'abl': []},
#     'count': 5}),
#   (1179653, {'refs': {'ldb': [], 'abl': []}, 'count': 0})])

# %%
useful_nodes = []
non_useful = []

for k in leaderboard_refs:
    if "count" in leaderboard_refs[k] and leaderboard_refs[k]["count"] > 0:
        useful_nodes.append(k)
    else:
        non_useful.append(k)
        
print(len(useful_nodes), len(non_useful))
# Out:
# 682 986

# %%
useful_nodes[0:2], non_useful[0:5]
# Out:
# ([1179651, 229423], [1179653, 1163279, 983062, 557082, 172080])

# %% [markdown]
# ### Ins0

# %%
nk = 1179653
iclr_ref_arxiv_map[nk], leaderboard_table_refs[nk]
# Out:
# ('1905.02249',
#  {'tcount': [9, 4, 5, 0],
#   'table_labels': [('leaderboard',),
#    ('leaderboard',),
#    ('ablation',),
#    ('ablation',),
#    ('ablation',),
#    ('leaderboard',),
#    ('ablation',),
#    ('ablation',),
#    ('leaderboard',)]})

# %%
paper = pc.get_by_id(iclr_ref_arxiv_map[nk])

# %%
paper.tables[0].df.loc[1,0]
# Out:
# (<axcell.data.table.Table at 0x7f0f4b9f04e0>,
#  Cell(value='Mean Teacher tarvainen2017weight', raw_value='Mean Teacher tarvainen2017weight', gold_tags='', refs=[], layout='border-t align-left header'))

# %% [markdown]
# # Ins1

# %%
nk = 557082
iclr_ref_arxiv_map[nk], leaderboard_table_refs[nk]
# Out:
# ('1411.2005', {'tcount': [1, 1, 0, 0], 'table_labels': [('leaderboard',)]})

# %%
paper = pc.get_by_id(iclr_ref_arxiv_map[nk])

# %%
paper.tables[0]
# Out:
# <style>
# ...
