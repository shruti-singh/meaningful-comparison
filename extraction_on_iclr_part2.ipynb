# %% [markdown]
# # Text and Tables Extraction on ICLR Data - PART2
#
# This is for the references of ICLR papers

# %%
import pickle
from collections import defaultdict
import re
import glob

# %%
from pathlib import Path
from axcell.helpers.paper_extractor import PaperExtractor
from axcell.data.paper_collection import PaperCollection
from axcell.models.structure import TableType, TableStructurePredictor, TableTypePredictor
# from axcell.helpers.results_extractor import ResultsExtractor

# %% [markdown]
# ## Load the paper references keys for steering

# %%
with open('iclr_ref_arxiv_map.pkl', "rb") as f:
    iclr_ref_arxiv_map = pickle.load(f)

# %% [markdown]
# ## Run extraction one by one

# %%
ROOT_PATH = Path('data')
MODELS_PATH = Path('models')

SOURCES_PATH = ROOT_PATH / 'sources'
PAPERS_PATH = ROOT_PATH / 'papers'

# %%
extract = PaperExtractor(ROOT_PATH)

# %%
models_path = Path(MODELS_PATH)
ttp = TableTypePredictor(models_path, "table-type-classifier.pth")
pc = PaperCollection.from_files(PAPERS_PATH)
# Out:
# [PID 113189] Load model table-type-classifier.pth

# %%
table_labels = {TableType.SOTA: 'leaderboard', TableType.ABLATION: 'ablation', TableType.IRRELEVANT: 'irrelevant'}

# %%
status_count = 0
err_count = 0
unextracted_papers = []
err_paper_ids = []
unextracted_paper_ids = []
status_count = max(len(leaderboard_table_refs), len(leaderboard_refs))
err_count = 0
errs_ids = []

leaderboard_table_refs = defaultdict(dict)
leaderboard_refs = defaultdict(dict)

# %%
already_computed = list(set(list(leaderboard_table_refs.keys()) + list(leaderboard_refs.keys())))

# %%
len(already_computed), already_computed[0:3], status_count, err_count, len(unextracted_papers)
# Out:
# (0, [], 0, 0, 0)

# %%
total = len(iclr_ref_arxiv_map)
count = 0

# First extract all - i.e. unpack and load htmls
for k, v in iclr_ref_arxiv_map.items():
    count += 1
    if count%10==0:
        print(count, total)
    try:
        path_split = v.split(".")
        # Extraction
        extract(SOURCES_PATH / path_split[0] / v)
    except Exception as ex:
        print(k, v)
# Out:
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 647191 1712.04248
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# 10 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 20 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 327763 hep-lat_0509019
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 30 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 40 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 50 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 60 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 70 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 80 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 835873 1705.02445
# 90 2328
# 598309 1412.2306
# 1188137 1907.10529
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 100 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 110 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 1139085 1710.03077
# 180622 1703.01161
# 606609 1703.00848
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 120 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 130 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 140 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 150 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 160 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 170 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 180 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 190 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 200 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 210 2328
# 541434 cs_0209010
# /home/singh_shruti/anaconda3/envs/axcell/lib/python3.7/site-packages/axcell/helpers/paper_extractor.py:26: UserWarning: Unable to infer arxiv_id from "cs_0209010" filename
#   warnings.warn(f'Unable to infer arxiv_id from "{source.name}" filename')
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 220 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 230 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 240 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 250 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 260 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 270 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 280 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 574447 hep-ph_0702172
# 549873 hep-ex_0507097
# 290 2328
# /home/singh_shruti/anaconda3/envs/axcell/lib/python3.7/site-packages/axcell/helpers/paper_extractor.py:26: UserWarning: Unable to infer arxiv_id from "hep-ph_0702172" filename
#   warnings.warn(f'Unable to infer arxiv_id from "{source.name}" filename')
# /home/singh_shruti/anaconda3/envs/axcell/lib/python3.7/site-packages/axcell/helpers/paper_extractor.py:26: UserWarning: Unable to infer arxiv_id from "hep-ex_0507097" filename
#   warnings.warn(f'Unable to infer arxiv_id from "{source.name}" filename')
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 300 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 310 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 320 2328
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# 330 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 340 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# 350 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 360 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 370 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# /home/singh_shruti/anaconda3/envs/axcell/lib/python3.7/site-packages/axcell/helpers/paper_extractor.py:26: UserWarning: Unable to infer arxiv_id from "math_9905121" filename
#   warnings.warn(f'Unable to infer arxiv_id from "{source.name}" filename')
# 214306 math_9905121
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# 763177 gr-qc_0404079
# Unpacked successfully
# /home/singh_shruti/anaconda3/envs/axcell/lib/python3.7/site-packages/axcell/helpers/paper_extractor.py:26: UserWarning: Unable to infer arxiv_id from "gr-qc_0404079" filename
#   warnings.warn(f'Unable to infer arxiv_id from "{source.name}" filename')
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# 380 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 390 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# /home/singh_shruti/anaconda3/envs/axcell/lib/python3.7/site-packages/axcell/helpers/paper_extractor.py:26: UserWarning: Unable to infer arxiv_id from "cmp-lg_9407020" filename
#   warnings.warn(f'Unable to infer arxiv_id from "{source.name}" filename')
# 1398 cmp-lg_9407020
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 400 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 410 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 420 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# /home/singh_shruti/anaconda3/envs/axcell/lib/python3.7/site-packages/axcell/helpers/paper_extractor.py:26: UserWarning: Unable to infer arxiv_id from "math_0612104" filename
#   warnings.warn(f'Unable to infer arxiv_id from "{source.name}" filename')
# 787948 math_0612104
# 430 2328
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 440 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 450 2328
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 460 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 470 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 480 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 490 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 500 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 510 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 520 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 530 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 540 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 550 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 560 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 570 2328
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 580 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 590 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 600 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 610 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 620 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 630 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# /home/singh_shruti/anaconda3/envs/axcell/lib/python3.7/site-packages/axcell/helpers/paper_extractor.py:26: UserWarning: Unable to infer arxiv_id from "physics_9806030" filename
#   warnings.warn(f'Unable to infer arxiv_id from "{source.name}" filename')
# 608552 physics_9806030
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 640 2328
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# 1059134 cmp-lg_9606011
# /home/singh_shruti/anaconda3/envs/axcell/lib/python3.7/site-packages/axcell/helpers/paper_extractor.py:26: UserWarning: Unable to infer arxiv_id from "cmp-lg_9606011" filename
#   warnings.warn(f'Unable to infer arxiv_id from "{source.name}" filename')
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 650 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 660 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 670 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# /home/singh_shruti/anaconda3/envs/axcell/lib/python3.7/site-packages/axcell/helpers/paper_extractor.py:26: UserWarning: Unable to infer arxiv_id from "cs_0009008" filename
#   warnings.warn(f'Unable to infer arxiv_id from "{source.name}" filename')
# 1132974 cs_0009008
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 680 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 690 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 700 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# 710 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 720 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# 730 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 740 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 750 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 760 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 770 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 780 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# /home/singh_shruti/anaconda3/envs/axcell/lib/python3.7/site-packages/axcell/helpers/paper_extractor.py:26: UserWarning: Unable to infer arxiv_id from "hep-ph_9704332" filename
#   warnings.warn(f'Unable to infer arxiv_id from "{source.name}" filename')
# 674625 hep-ph_9704332
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 790 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 800 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 810 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 820 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 830 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 840 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 850 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 860 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# /home/singh_shruti/anaconda3/envs/axcell/lib/python3.7/site-packages/axcell/helpers/paper_extractor.py:26: UserWarning: Unable to infer arxiv_id from "hep-th_9707250" filename
#   warnings.warn(f'Unable to infer arxiv_id from "{source.name}" filename')
# 412794 hep-th_9707250
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 870 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 880 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 890 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# LaTeXML was unable to convert source code of this paper
# Unpacked successfully
# html conversion successful
# 900 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 910 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# 920 2328
# Unpacked successfully
# html conversion successful
# Unpacked successfully
# html conversion successful
# Unpacked successfully

# %%
for k, v in iclr_ref_arxiv_map.items():
    if not (k in already_computed or k in err_paper_ids or k in unextracted_paper_ids):
        if v:
            if status_count % 10 == 0:
                print("Status: ", status_count)
                with open("REF_leaderboard_table_refs.pkl", "wb") as some_file:
                    pickle.dump(leaderboard_table_refs, some_file)
                with open("REF_leaderboard_refs.pkl", "wb") as some_file:
                    pickle.dump(leaderboard_refs, some_file)
                    
            try:
                path_split = v.split(".")

                # Extraction
                # extract(SOURCES_PATH / path_split[0] / v)

                paper = pc.get_by_id(v)
                
                if not paper:
                    unextracted_papers.append((k, v))
                    continue
                
                print(k)
                
                if len(paper.tables) > 0:                    
                    # Add table type if absent
                    if paper.tables[0].gold_tags == "":
                        tables_types = ttp.predict(paper, paper.tables)
                        for table, table_type in zip(paper.tables, tables_types):
                            table.gold_tags = table_labels[table_type]
                    
                    #Count the different types of tables
                    table_type_count = [0, 0, 0]
                    for tt in paper.tables:
                        if tt.gold_tags.lower().strip() == "leaderboard":
                            table_type_count[0] = table_type_count[0] + 1
                        elif tt.gold_tags.lower().strip() == "ablation":
                            table_type_count[1] = table_type_count[1] + 1
                        elif tt.gold_tags.lower().strip() == "irrelevant":
                            table_type_count[2] = table_type_count[2] + 1
                        else:
                            print("Unknown table type: ", tt.gold_tags)
                    
                    # Save table stat in leaderboard_table_refs
                    leaderboard_table_refs[k]["tcount"] = [len(paper.tables), table_type_count[0], table_type_count[1], table_type_count[2]]
                else:
                    leaderboard_table_refs[k]["tcount"] = [0, 0, 0, 0]
                
                leaderboard_table_refs[k]["table_labels"] = []
                for tablerol in paper.tables:
                    leaderboard_table_refs[k]["table_labels"].append((tablerol.gold_tags,))
                
                if (leaderboard_table_refs[k]["tcount"][1]+leaderboard_table_refs[k]["tcount"][2]) > 0:
                    leaderboard_refs[k]["refs"] = {}
                
                # If sota/leaderboard tables present, extract references from them
                if leaderboard_table_refs[k]["tcount"][1] > 0:
                    leaderboard_refs[k]["refs"]["ldb"] = []
                    leaderboard_refs[k]["count"] = 0
                    for iterid, table in enumerate(paper.tables):
                        idx = iterid + 1
                        if table.gold_tags == "leaderboard":
                            
                            table_dir_path = "/home/singh_shruti/workspace/axcell_ws/axcell/notebooks/data/papers/" + path_split[0] + "/" + v
                            table_files = glob.glob(table_dir_path+"/*.csv")
                            table_files_stripped = [tfs.rsplit("/", 1)[1] for tfs in table_files]
                            
                            candidate_name = "table_" + "{:02d}".format(idx) + ".csv"
                            if candidate_name in table_files_stripped:
                                cannot_use_f = open(table_dir_path + "/" + candidate_name, "r")
                                for line in cannot_use_f:
                                    m = re.findall("<ref id=[0-9a-zA-Z'-]*>[a-zA-Z 0-9\.]*</ref>", line)
                                    for iim in m:
                                        leaderboard_refs[k]["refs"]["ldb"].append(iim)
                                        leaderboard_refs[k]["count"] += 1
                            else:
                                print("For {} cannot find leaderboard table file: {}".format(k, candidate_name))
                            
                    leaderboard_refs[k]["refs"]["ldb"] = list(set(leaderboard_refs[k]["refs"]["ldb"]))
                    
                if leaderboard_table_refs[k]["tcount"][2] > 0:
                    leaderboard_refs[k]["refs"]["abl"] = []
                    for iterid, table in enumerate(paper.tables):
                        idx = iterid + 1
                        if table.gold_tags == "ablation":
                            
                            table_dir_path = "/home/singh_shruti/workspace/axcell_ws/axcell/notebooks/data/papers/" + path_split[0] + "/" + v
                            table_files = glob.glob(table_dir_path+"/*.csv")
                            table_files_stripped = [tfs.rsplit("/", 1)[1] for tfs in table_files]
                            
                            candidate_name = "table_" + "{:02d}".format(idx) + ".csv"
                            if candidate_name in table_files_stripped:
                                cannot_use_f = open(table_dir_path + "/" + candidate_name, "r")
                                for line in cannot_use_f:
                                    m = re.findall("<ref id=[0-9a-zA-Z'-]*>[a-zA-Z 0-9\.]*</ref>", line)
                                    for iim in m:
                                        leaderboard_refs[k]["refs"]["abl"].append(iim)
                            else:
                                print("For {} cannot find ablation table file: {}".format(k, candidate_name))
                            
                    leaderboard_refs[k]["refs"]["abl"] = list(set(leaderboard_refs[k]["refs"]["abl"]))
                            
                status_count += 1
            except Exception as ex:
                print(k, v)
                print("Error: ", ex)
                err_count += 1
                errs_ids.append((k, v))
# Out:
# Status:  0
# Unpacked successfully
# html conversion successful
# 1179651
# Unpacked successfully
# html conversion successful
# 1179653
# Unpacked successfully
# html conversion successful
# 598027
# Unpacked successfully
# html conversion successful
# 1163279
# Unpacked successfully
# html conversion successful
# 557076
# Unpacked successfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-0e2c8e1cd379> in <module>
#      13
#      14                 # Extraction
# ---> 15                 extract(SOURCES_PATH / path_split[0] / v)
#      16
#      17                 paper = pc.get_by_id(v)
#
# ~/anaconda3/envs/axcell/lib/python3.7/site-packages/axcell/helpers/paper_extractor.py in __call__(self, source)
#      40         html_path = self.root / 'htmls' / subpath / 'index.html'
#      41         try:
# ---> 42             html = self.latex.to_html(unpack_path)
#      43             print("html conversion successful")
#      44             html_path.parent.mkdir(parents=True, exist_ok=True)
#
# ~/anaconda3/envs/axcell/lib/python3.7/site-packages/axcell/helpers/latex_converter.py in to_html(self, source_dir)
#      78             output_dir = Path(output_dir)
#      79             try:
# ---> 80                 self.latex2html(source_dir, output_dir)
#      81                 return self.clean_html(output_dir / "index.html")
#      82             except ContainerError as err:
#
# ~/anaconda3/envs/axcell/lib/python3.7/site-packages/axcell/helpers/latex_converter.py in latex2html(self, source_dir, output_dir, use_named_volumes)
#      59
#      60         try:
# ---> 61             self.client.containers.run("arxivvanity/engrafo:b3db888fefa118eacf4f13566204b68ce100b3a6", command, remove=True, volumes=volumes)
#      62         except ContainerError as err:
#      63             if err.exit_status == MAGIC_EXIT_ERROR:
#
# ~/anaconda3/envs/axcell/lib/python3.7/site-packages/docker/models/containers.py in run(self, image, command, stdout, stderr, remove, **kwargs)
#     820             )
#     821
# --> 822         exit_status = container.wait()['StatusCode']
#     823         if exit_status != 0:
#     824             out = None
#
# ~/anaconda3/envs/axcell/lib/python3.7/site-packages/docker/models/containers.py in wait(self, **kwargs)
#     506                 If the server returns an error.
#     507         """
# --> 508         return self.client.api.wait(self.id, **kwargs)
#     509
#     510
#
# ~/anaconda3/envs/axcell/lib/python3.7/site-packages/docker/utils/decorators.py in wrapped(self, resource_id, *args, **kwargs)
#      17                     'Resource ID was not provided'
#      18                 )
# ---> 19             return f(self, resource_id, *args, **kwargs)
#      20         return wrapped
#      21     return decorator
#
# ~/anaconda3/envs/axcell/lib/python3.7/site-packages/docker/api/container.py in wait(self, container, timeout, condition)
#    1287             params['condition'] = condition
#    1288
# -> 1289         res = self._post(url, timeout=timeout, params=params)
#    1290         return self._result(res, True)
#
# ~/anaconda3/envs/axcell/lib/python3.7/site-packages/docker/utils/decorators.py in inner(self, *args, **kwargs)
#      44             else:
#      45                 kwargs['headers'].update(self._general_configs['HttpHeaders'])
# ---> 46         return f(self, *args, **kwargs)
#      47     return inner
#
# ~/anaconda3/envs/axcell/lib/python3.7/site-packages/docker/api/client.py in _post(self, url, **kwargs)
#     224     @update_headers
#     225     def _post(self, url, **kwargs):
# --> 226         return self.post(url, **self._set_request_timeout(kwargs))
#     227
#     228     @update_headers
#
# ~/anaconda3/envs/axcell/lib/python3.7/site-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     576         """
#     577
# --> 578         return self.request('POST', url, data=data, json=json, **kwargs)
#     579
#     580     def put(self, url, data=None, **kwargs):
#
# ~/anaconda3/envs/axcell/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/anaconda3/envs/axcell/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     681
#     682         if not stream:
# --> 683             r.content
#     684
#     685         return r
#
# ~/anaconda3/envs/axcell/lib/python3.7/site-packages/requests/models.py in content(self)
#     827                 self._content = None
#     828             else:
# --> 829                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     830
#     831         self._content_consumed = True
#
# ~/anaconda3/envs/axcell/lib/python3.7/site-packages/requests/models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# ~/anaconda3/envs/axcell/lib/python3.7/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# ~/anaconda3/envs/axcell/lib/python3.7/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     762
#     763             while True:
# --> 764                 self._update_chunk_length()
#     765                 if self.chunk_left == 0:
#     766                     break
#
# ~/anaconda3/envs/axcell/lib/python3.7/site-packages/urllib3/response.py in _update_chunk_length(self)
#     692         if self.chunk_left is not None:
#     693             return
# --> 694         line = self._fp.fp.readline()
#     695         line = line.split(b";", 1)[0]
#     696         try:
#
# ~/anaconda3/envs/axcell/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
